# %% [markdown]
# # Lab 4

# %% [markdown]
# NAME : MANASWINI SAHOO
#
#   ROLL:1906563

# %% [markdown]
# 1) WAP in python that uses class to store the name and marks of the students. Use
# a list to store the marks in three subjects.

# %%
class students:
    count = 0
    def __init__(self, name):
        self.name = name
        self.marks = []
        students.count = students.count + 1
        
    def enterMarks(self):
        for i in range(3):
            m = int(input("Enter the marks of %s in %d subject: "%(self.name, i+1)))
            self.marks.append(m)
            
    def display(self):
        print (self.name, "got ", self.marks)
             
name = input("Enter the name of Student:")
s1 = students(name)
s1.enterMarks()
s1.display()
print ("")

name = input("Enter the name of Student:")
s2 = students(name)
s2.enterMarks()
s2.display()
# Out:
# Enter the name of Student:mnop
# Enter the marks of mnop in 1 subject: 67
# Enter the marks of mnop in 2 subject: 78
# Enter the marks of mnop in 3 subject: 89
# mnop got  [67, 78, 89]
#
# Enter the name of Student:pqrs
# Enter the marks of pqrs in 1 subject: 98
# Enter the marks of pqrs in 2 subject: 92
# Enter the marks of pqrs in 3 subject: 77
# pqrs got  [98, 92, 77]

# %% [markdown]
# 2) WAP in python with class Employee that keeps a track of the number of
# employees in an organization and also stores their name, designation and
# salary details.

# %%
class Employee:
    count = 0
    def __init__(self, name, des, salary):
        self.name = name
        self.des = des
        self.salary = salary
        Employee.count = Employee.count + 1
    
    def displayCount(self):
        print("The number of employees in the organization are: ", self.count)
        
    def displayEmp(self):
        print ("Name of Employee is: ", self.name)
        print ("Designation of Employee: ", self.des)
        print ("Salary of Employee: ", self.salary)
        
e1 = Employee ("abcd", "Manager", 90000)
e2 = Employee ("pqrs", "Data scientist", 70000)

e1.displayCount()

print("Employee Details is:")

e1.displayEmp()
e2.displayEmp()
# Out:
# The number of employees in the organization are:  2
# Employee Details is:
# Name of Employee is:  Mahesh
# Designation of Employee:  Manager
# Salary of Employee:  20000
# Name of Employee is:  Rahul
# Designation of Employee:  Team Leader
# Salary of Employee:  30000

# %% [markdown]
# 3) WAP in python has a class Person storing name and date of birth of a person. The
# program should subtract the date of birth from today’s date to find out if the person
# is eligible to vote or not.

# %%
import datetime
class person():
    def __init__(self, name, dob):
        self.name=name
        self.dob=dob

    def check(self):
        today=datetime.date.today()
        age=today.year-self.dob.year
        if today< datetime.date(today.year, self.dob.month, self.dob.day):
            age-=1
        if age>=18:
            print(self.name," ,You are eligible to vote.")
        else:
            print(self.name," ,Sorry! You are not eligible to cast your vote.")

p=person("Roshni", datetime.date(2002, 1, 2))
p.check()
# Out:
# Roshni  ,You are eligible to vote.

# %% [markdown]
# 4) WAP in python has a class Circle. Use a class variable that defines the value
# of constant Pie value=3.14. Use this class variable to calculate the
# area and circumference of the circle with specified radius.

# %%
class Circle():
    def __init__(self, r):
        self.radius = r

    def area(self):
        return self.radius**2*3.14
    
    def perimeter(self):
        return 2*self.radius*3.14


NewCircle = Circle(15)

print(NewCircle.area())

print(NewCircle.perimeter())
# Out:
# 706.5
# 94.2

# %% [markdown]
# 5) WAP in python that has a class Student that stores the name ,roll no, marks(in
# three subjects). And display the information(name, roll no, total marks) stored
# about the students.

# %%
class Student:
    marks = []
    def getData(self, rn, name, m1, m2, m3):
        Student.rn = rn
        Student.name = name
        Student.marks.append(m1)
        Student.marks.append(m2)
        Student.marks.append(m3)

        
    def displayData(self):
        print ("Roll Number is: ", Student.rn)
        print ("Name is: ", Student.name)
        print ("Marks are: ", Student.marks)
        print ("Total Marks are: ", self.total())
        print ("Average Marks are: ", self.average())

        
    def total(self):
        return (Student.marks[0] + Student.marks[1] +Student.marks[2])

    
    def average(self):
        return ((Student.marks[0] + Student.marks[1] +Student.marks[2])/3)

    
r = int (input("Enter the roll number: "))
name = input("Enter the name: ")
m1 = int (input("Enter the marks in the first subject: "))
m2 = int (input("Enter the marks in the second subject: "))
m3 = int (input("Enter the marks in the third subject: "))


s1 = Student()
s1.getData(r, name, m1, m2, m3)
s1.displayData()
# Out:
# Enter the roll number: 1906563
# Enter the name: Roshni
# Enter the marks in the first subject: 98
# Enter the marks in the second subject: 78
# Enter the marks in the third subject: 65
# Roll Number is:  1906563
# Name is:  Roshni
# Marks are:  [98, 78, 65]
# Total Marks are:  241
# Average Marks are:  80.33333333333333

# %% [markdown]
# 6) WAP in python that has a class Rectangle with attribute length and breadth
# and a method area that returns the area of the rectangle.

# %%
class Rectangle():
    def __init__(self, l, w):
        self.length = l
        self.width  = w

    def rectangle_area(self):
        return self.length*self.width

newRectangle = Rectangle(15, 7)
print("area is :",newRectangle.rectangle_area())
# Out:
# area is : 105

# %% [markdown]
# 7) WAP in python that has a class Fraction with attributesnumerator
# and denominator. Enter the values to the attributes and print the
# function in simplified forms.

# %%
class fraction:

  def __init__(self,num,den):
    self.num=num
    self.den=den

  def display(self):
    print(self.num,"/",self.den)

obj=fraction(2,3)
obj.display()
# Out:
# 2 / 3

# %% [markdown]
# 8) WAP in python has an abstract class Polygon. Derive two classes Rectangle and
# Triangle from polygon and write methods to get the details of their dimensions and
# hence calculate the area.

# %%
class Polygon:
   def __init__(self, n):
        self.number_of_sides = n
  
   def print_num_sides(self):
        print('There are ' + str(self.number_of_sides) + ' sides.')

class Rectangle(Polygon):
   def __init__(self, lenghts_of_sides):
        Polygon.__init__(self, 4)
        self.lengths_of_sides = lenghts_of_sides  

   def get_area(self):
        x, y = self.lenghts_of_sides
        return x * y

 
class Triangle(Polygon):
   def __init__(self, lengths_of_sides):
        Polygon.__init__(self, 3)
        self.lengths_of_sides = lengths_of_sides 

   def get_area(self):
        a, b, c = self.lengths_of_sides
        s = (a + b + c) / 2
        return (s*(s-a)*(s-b)*(s-c)) ** 0.5

p = Polygon(8)
p.print_num_sides()

tri = Triangle([6, 7, 8])
print("area of triangle :",tri.get_area())

tri.print_num_sides()
# Out:
# There are 8 sides.
# area of triangle : 20.33316256758894
# There are 3 sides.

# %% [markdown]
# 9) WAP in python with class Bill. The users have the option to pay the bill by card or
# by cash. Use the inheritance to model this situation.

# %%
class Bill:
    def __init__(self):
        self.balance=10000
        print("Hello!!!Please pay ur bill by cash or card !")
 
    def paid(self):
        amount=float(input("Enter amount to be paid: "))
        self.balance += amount
        print("\n Amount paid:",amount)
 
    def display(self):
        print("\n Net Balance after payment=",self.balance)


s = Bill()
s.paid()
s.display()
# Out:
# Hello!!!Please pay ur bill by cash or card !
# Enter amount to be paid: 30000
#
#  Amount paid: 30000.0
#
#  Net Balance after payment= 40000.0

# %% [markdown]
# 10) WAP in python has a class Person. Inherit a class Faculty from a person which
# also has a class publications.

# %%
class Person(object):

    def __init__(self, name):
        self.name = name

    def getName(self):
        return self.name

    def isFaculty(self):
        return False

class Faculty(Person):

    def isFaculty(self):
        return True

class Publication(Faculty):

   def ispublish(self):
     return True

fac1 = Person("mnop")  
print(fac1.getName(), fac1.isFaculty())
  
fac2 = Faculty("abcd") 
print(fac2.getName(), fac2.isFaculty())

fac3 = Publication("Research paper")
print(fac3.getName(),fac3.ispublish())
# Out:
# mnop False
# abcd True
# Research paper True
